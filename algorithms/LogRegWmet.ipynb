# %%
# imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('accident.csv')

# %%
df
# Out:
#       Unnamed: 0   LONGITUDE   LATITUDE  SPD      LEN    ACC      VOL  F85th  \
# 0              0 -121.803753  37.227881   35   3200.0   18.0   8100.0   40.0
# 1              1 -121.791060  37.225223   25   3362.0    4.0   2550.0   29.0
# 2              2 -121.862273  37.341412   25   4400.0   42.0   7550.0   29.5
# 3              3 -121.900218  37.331962   25   1580.0    5.0   3000.0   29.5
# 4              4 -121.860729  37.358019   40  13100.0  281.0  29500.0   41.3
# ...          ...         ...        ...  ...      ...    ...      ...    ...
# 4347        4347 -121.882064  37.221661   35   8750.0   30.0  10800.0   39.3
# 4348        4348 -121.871737  37.396813   35   7300.0   28.0  14300.0   39.5
# 4349        4349 -121.791719  37.314021   40  10990.0   71.0  25800.0   43.7
# 4350        4350 -121.891325  37.307313   25   3600.0   21.0  11700.0   29.5
# 4351        4351 -121.797626  37.329070   25   3900.0   11.0   1480.0   34.0
#
#       LOCAL  F50th  Precip  Air max  min   obs  hour  Accident
# 0         0   36.0    0.00       83   57  70.0  17.0         0
# 1         0   26.0    0.07       67   47  57.0   7.0         0
# 2         0   26.0    0.00       82   59  70.5   0.0         0
# 3         0   26.0    0.02       69   49  59.0  19.0         0
# 4         0   37.3    0.07       59   42  50.5   3.0         0
# ...     ...    ...     ...      ...  ...   ...   ...       ...
# 4347      0   36.0    0.06       57   41  49.0  11.0         0
# 4348      0   35.5    0.12       58   42  50.0   5.0         0
# 4349      0   39.3    0.01       76   52  64.0  12.0         0
# 4350      0   26.5    0.02       69   49  59.0  23.0         0
# 4351      1   25.0    0.04       74   53  63.5   7.0         0
#
# [4352 rows x 16 columns]

# %%
df.shape
# Out:
# (4352, 16)

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# LONGITUDE     float64
# LATITUDE      float64
# SPD             int64
# LEN           float64
# ACC           float64
# VOL           float64
# F85th         float64
# LOCAL           int64
# F50th         float64
# Precip        float64
# Air max         int64
# min             int64
# obs           float64
# hour          float64
# Accident        int64
# dtype: object

# %%
df
# Out:
#       Unnamed: 0   LONGITUDE   LATITUDE  SPD      LEN    ACC      VOL  F85th  \
# 0              0 -121.803753  37.227881   35   3200.0   18.0   8100.0   40.0
# 1              1 -121.791060  37.225223   25   3362.0    4.0   2550.0   29.0
# 2              2 -121.862273  37.341412   25   4400.0   42.0   7550.0   29.5
# 3              3 -121.900218  37.331962   25   1580.0    5.0   3000.0   29.5
# 4              4 -121.860729  37.358019   40  13100.0  281.0  29500.0   41.3
# ...          ...         ...        ...  ...      ...    ...      ...    ...
# 4347        4347 -121.882064  37.221661   35   8750.0   30.0  10800.0   39.3
# 4348        4348 -121.871737  37.396813   35   7300.0   28.0  14300.0   39.5
# 4349        4349 -121.791719  37.314021   40  10990.0   71.0  25800.0   43.7
# 4350        4350 -121.891325  37.307313   25   3600.0   21.0  11700.0   29.5
# 4351        4351 -121.797626  37.329070   25   3900.0   11.0   1480.0   34.0
#
#       LOCAL  F50th  Precip  Air max  min   obs  hour  Accident
# 0         0   36.0    0.00       83   57  70.0  17.0         0
# 1         0   26.0    0.07       67   47  57.0   7.0         0
# 2         0   26.0    0.00       82   59  70.5   0.0         0
# 3         0   26.0    0.02       69   49  59.0  19.0         0
# 4         0   37.3    0.07       59   42  50.5   3.0         0
# ...     ...    ...     ...      ...  ...   ...   ...       ...
# 4347      0   36.0    0.06       57   41  49.0  11.0         0
# 4348      0   35.5    0.12       58   42  50.0   5.0         0
# 4349      0   39.3    0.01       76   52  64.0  12.0         0
# 4350      0   26.5    0.02       69   49  59.0  23.0         0
# 4351      1   25.0    0.04       74   53  63.5   7.0         0
#
# [4352 rows x 16 columns]

# %%
feature_cols = ['SPD', 'ACC', 'Precip', 'Air max','min','obs']
X = df[feature_cols] # Features
y = df.Accident # Target variable

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression()

# fit the model with data
logreg.fit(X_train,y_train)

#
y_pred=logreg.predict(X_test)
# Out:
# /Library/Python/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[1049,    6],
#        [ 251,    0]])

# %%
# import required modules
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8032159264931087
