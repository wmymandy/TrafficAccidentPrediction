# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import array

# %% [markdown]
# read traffic speed cvs

# %%
speed = pd.read_csv("Speed_Pub.csv")
speed.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4e00e7529bbd> in <module>
# ----> 1 speed = pd.read_csv("Speed_Pub.csv")
#       2 speed.keys()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Move irrelavate features

# %%
speed = speed.drop(["OBJECTID","ROUTE","DATE","on_hold", "CD", "PD", "GlobalID","reason_for_on_hold", "Comment", "GlobalID", "Jurisdiction", "NEW", "MEAN_SPD","BGN_PACE","PRCNT_PACE","Shape__Length","RATE","TYPE"],axis=1)
speed.head(10)
# Out:
#        STREET              START             END_  SPD     LEN   ACC      VOL  \
# 0  AIRPORT BL         COLEMAN AV       SKYPORT DR   35  7200.0   7.0  14450.0
# 1  AIRPORT PW         AIRPORT BL        MATRIX BL   35  2500.0  13.0  18350.0
# 2    ALLEN AV    SANTA TERESA BL  BLOSSOM HILL RD   30  3700.0   5.0   3500.0
# 3    ALMA  AV           FIRST ST        SENTER RD   35  3970.0  20.0   9300.0
# 4     ALMA AV            VINE ST         FIRST ST   30  2000.0  47.0  17000.0
# 5     ALMA AV       MINNESOTA ST         VINE  ST   35  2950.0  29.0  13200.0
# 6  ALMADEN AV            ALMA AV          REED ST   30  5000.0  50.0   7900.0
# 7  ALMADEN BL  100' N/O GRANT ST   SANTA CLARA ST   30  4300.0  22.0  13100.0
# 8  ALMADEN EX              SR-87      SAN JOSE AV   45  2200.0   9.0  13500.0
# 9  ALMADEN EX        SAN JOSE AV          ALMA AV   40  2100.0  33.0  20200.0
#
#    F85th  LOCAL  F50th
# 0   41.0      0   37.0
# 1   39.0      0   35.0
# 2   32.5      0   28.5
# 3   37.5      0   34.0
# 4   33.0      0   30.0
# 5   37.5      0   34.5
# 6   33.3      0   30.0
# 7   33.5      0   29.0
# 8   48.0      0   44.0
# 9   42.0      0   38.0

# %%
speed.keys()
# Out:
# Index(['STREET', 'START', 'END_', 'SPD', 'LEN', 'ACC', 'VOL', 'F85th', 'LOCAL',
#        'F50th'],
#       dtype='object')

# %%
speed.sort_values('VOL', ascending= False).iloc[:10,:]
# Out:
#               STREET            START              END_  SPD      LEN    ACC  \
# 477       ALMADEN EX       COLEMAN RD        BRANHAM LN   45   6900.0  288.0
# 70        CAPITOL EX    McLAUGHLIN AV             I-680   45  23000.0  670.0
# 24        CAPITOL EX            SR-87     McLAUGHLIN AV   50  60450.0  670.0
# 332      SARATOGA AV      MOORPARK AV  STEVENS CREEK BL   35   3150.0  140.0
# 483  SANTA TERESA BL  BLOSSOM HILL RD             SR-85   40   2160.0   60.0
# 252        MURPHY AV       OAKLAND RD          LUNDY AV   40   3320.0   22.0
# 162     HOSTETTER RD         LUNDY AV        CAPITOL AV   40   5570.0  116.0
# 392         TULLY RD      MONTEREY RD        CAPITOL EX   40  17800.0  240.0
# 53         BROKAW RD        MATRIX BL        OAKLAND RD   40   8550.0   97.0
# 31      BERRYESSA RD        MABURY RD        CAPITOL AV   40  11500.0  159.0
#
#          VOL  F85th  LOCAL  F50th
# 477  64000.0   52.0      0   48.0
# 70   60450.0   50.0      0   46.0
# 24   50900.0   51.0      0   46.0
# 332  49450.0   39.0      0   35.0
# 483  46750.0   41.0      0   37.0
# 252  45900.0   44.5      0   41.0
# 162  42900.0   42.5      0   39.0
# 392  40700.0   42.3      0   38.0
# 53   40600.0   42.0      0   38.3
# 31   40150.0   43.3      0   39.7

# %% [markdown]
# add latitude and longitude for each item using google map geocoder

# %%
import requests
import googlemaps
import os

gmaps = googlemaps.Client(key='AIzaSyAbDfjZYGZhSPC60ZxAfYEm1yKxV77zQfw')

speed['lat'] = ""
speed['lng'] = ""

speed['intersection1'] = speed['STREET'] + ' & ' + speed['START'] +', San Jose'
speed['intersection2'] = speed['START']  + ' & ' + speed['STREET'] +', San Jose'
speed['intersection3'] = speed['STREET'] + ' & ' + speed['END_'] +', San Jose'
speed['intersection4'] = speed['END_'] + ' & ' + speed['STREET'] +', San Jose'

a = 0
for i in range(0,speed.shape[0]):
    item = speed.iloc[i]
    address0 = item.intersection1
    address1 = item.intersection3
    geocode_result0 = gmaps.geocode(address0)
    geocode_result1 = gmaps.geocode(address1)
    if len(geocode_result0) != 0:
        speed.at[i, 'lat'] = geocode_result0[0]["geometry"]["location"]["lat"]
        speed.at[i, 'lng']  = geocode_result0[0]["geometry"]["location"]["lng"]
        a = a + 1
    elif len(geocode_result1) != 0:
        speed.at[i, 'lat'] = geocode_result1[0]["geometry"]["location"]["lat"]
        speed.at[i, 'lng'] = geocode_result1[0]["geometry"]["location"]["lng"]
        a = a + 1

speed.head(10)
# Out:
#        STREET              START             END_  SPD     LEN   ACC      VOL  \
# 0  AIRPORT BL         COLEMAN AV       SKYPORT DR   35  7200.0   7.0  14450.0
# 1  AIRPORT PW         AIRPORT BL        MATRIX BL   35  2500.0  13.0  18350.0
# 2    ALLEN AV    SANTA TERESA BL  BLOSSOM HILL RD   30  3700.0   5.0   3500.0
# 3    ALMA  AV           FIRST ST        SENTER RD   35  3970.0  20.0   9300.0
# 4     ALMA AV            VINE ST         FIRST ST   30  2000.0  47.0  17000.0
# 5     ALMA AV       MINNESOTA ST         VINE  ST   35  2950.0  29.0  13200.0
# 6  ALMADEN AV            ALMA AV          REED ST   30  5000.0  50.0   7900.0
# 7  ALMADEN BL  100' N/O GRANT ST   SANTA CLARA ST   30  4300.0  22.0  13100.0
# 8  ALMADEN EX              SR-87      SAN JOSE AV   45  2200.0   9.0  13500.0
# 9  ALMADEN EX        SAN JOSE AV          ALMA AV   40  2100.0  33.0  20200.0
#
#    F85th  LOCAL  F50th      lat      lng  \
# 0   41.0      0   37.0  37.3507 -121.921
# 1   39.0      0   35.0  37.3639 -121.929
# 2   32.5      0   28.5  37.2405 -121.858
# 3   37.5      0   34.0  37.3164 -121.874
# 4   33.0      0   30.0  37.3128 -121.879
# 5   37.5      0   34.5  37.3089 -121.888
# 6   33.3      0   30.0  37.3135 -121.878
# 7   33.5      0   29.0  37.3323 -121.894
# 8   48.0      0   44.0   37.189 -121.845
# 9   42.0      0   38.0  37.3074 -121.878
#
#                               intersection1  \
# 0         AIRPORT BL & COLEMAN AV, San Jose
# 1         AIRPORT PW & AIRPORT BL, San Jose
# 2      ALLEN AV & SANTA TERESA BL, San Jose
# 3             ALMA  AV & FIRST ST, San Jose
# 4               ALMA AV & VINE ST, San Jose
# 5          ALMA AV & MINNESOTA ST, San Jose
# 6            ALMADEN AV & ALMA AV, San Jose
# 7  ALMADEN BL & 100' N/O GRANT ST, San Jose
# 8              ALMADEN EX & SR-87, San Jose
# 9        ALMADEN EX & SAN JOSE AV, San Jose
#
#                               intersection2  \
# 0         COLEMAN AV & AIRPORT BL, San Jose
# 1         AIRPORT BL & AIRPORT PW, San Jose
# 2      SANTA TERESA BL & ALLEN AV, San Jose
# 3             FIRST ST & ALMA  AV, San Jose
# 4               VINE ST & ALMA AV, San Jose
# 5          MINNESOTA ST & ALMA AV, San Jose
# 6            ALMA AV & ALMADEN AV, San Jose
# 7  100' N/O GRANT ST & ALMADEN BL, San Jose
# 8              SR-87 & ALMADEN EX, San Jose
# 9        SAN JOSE AV & ALMADEN EX, San Jose
#
#                            intersection3  \
# 0      AIRPORT BL & SKYPORT DR, San Jose
# 1       AIRPORT PW & MATRIX BL, San Jose
# 2   ALLEN AV & BLOSSOM HILL RD, San Jose
# 3         ALMA  AV & SENTER RD, San Jose
# 4           ALMA AV & FIRST ST, San Jose
# 5           ALMA AV & VINE  ST, San Jose
# 6         ALMADEN AV & REED ST, San Jose
# 7  ALMADEN BL & SANTA CLARA ST, San Jose
# 8     ALMADEN EX & SAN JOSE AV, San Jose
# 9         ALMADEN EX & ALMA AV, San Jose
#
#                            intersection4
# 0      SKYPORT DR & AIRPORT BL, San Jose
# 1       MATRIX BL & AIRPORT PW, San Jose
# 2   BLOSSOM HILL RD & ALLEN AV, San Jose
# 3         SENTER RD & ALMA  AV, San Jose
# 4           FIRST ST & ALMA AV, San Jose
# 5           VINE  ST & ALMA AV, San Jose
# 6         REED ST & ALMADEN AV, San Jose
# 7  SANTA CLARA ST & ALMADEN BL, San Jose
# 8     SAN JOSE AV & ALMADEN EX, San Jose
# 9         ALMA AV & ALMADEN EX, San Jose

# %%
speed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 16 columns):
# STREET           580 non-null object
# START            580 non-null object
# END_             580 non-null object
# SPD              580 non-null int64
# LEN              575 non-null float64
# ACC              577 non-null float64
# VOL              576 non-null float64
# F85th            573 non-null float64
# LOCAL            580 non-null int64
# F50th            512 non-null float64
# lat              580 non-null object
# lng              580 non-null object
# intersection1    580 non-null object
# intersection2    580 non-null object
# intersection3    580 non-null object
# intersection4    580 non-null object
# dtypes: float64(5), int64(2), object(9)
# memory usage: 72.6+ KB

# %% [markdown]
# change latitude lagitud to float type

# %%
speed['lat'] = speed.lat.convert_objects(convert_numeric=True)
speed['lng'] = speed.lng.convert_objects(convert_numeric=True)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
speed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 16 columns):
# STREET           580 non-null object
# START            580 non-null object
# END_             580 non-null object
# SPD              580 non-null int64
# LEN              575 non-null float64
# ACC              577 non-null float64
# VOL              576 non-null float64
# F85th            573 non-null float64
# LOCAL            580 non-null int64
# F50th            512 non-null float64
# lat              580 non-null float64
# lng              580 non-null float64
# intersection1    580 non-null object
# intersection2    580 non-null object
# intersection3    580 non-null object
# intersection4    580 non-null object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 72.6+ KB

# %% [markdown]
# fill in F85th NA and F50th NA

# %%
value85  = 1.1* speed['SPD']
value50 = speed['SPD']
speed['F85th'] = value85.where(speed['F85th'] == np.nan, speed['F85th'])
speed['F50th'] = value50.where(speed['F50th'] == np.nan, speed['F50th'])

# %%
speed[speed.isnull().any(axis=1)].head()
# Out:
#                STREET           START             END_  SPD     LEN   ACC  \
# 13       ALUM ROCK AV      MANNING AV  MT. HAMILTON RD   40  7000.0  46.0
# 14       ALUM ROCK RD  CANON VISTA DR    EAST TERMINUS   15  6330.0   6.0
# 43   BLUEFIELD DR (L)      CAPITOL EX     ROSENBAUM AV   25  4700.0  12.0
# 46      BONITA AV (L)        SUNNY CT        HERALD AV   25  1350.0   4.0
# 58  CALCATERRA DR (L)    RAJKOVICH WY   SPRING HILL WY   30  4500.0   1.0
#
#         VOL  F85th  LOCAL  F50th        lat         lng  \
# 13      NaN   41.0      0    NaN  37.366987 -121.826767
# 14    600.0   22.0      0    NaN  37.392495 -121.819545
# 43  13000.0   34.0      1    NaN  37.271463 -121.845629
# 46   1200.0   31.0      1    NaN  37.341945 -121.859508
# 58   3200.0   34.0      1    NaN  37.203897 -121.844781
#
#                                  intersection1  \
# 13         ALUM ROCK AV & MANNING AV, San Jose
# 14     ALUM ROCK RD & CANON VISTA DR, San Jose
# 43     BLUEFIELD DR (L) & CAPITOL EX, San Jose
# 46          BONITA AV (L) & SUNNY CT, San Jose
# 58  CALCATERRA DR (L) & RAJKOVICH WY, San Jose
#
#                                  intersection2  \
# 13         MANNING AV & ALUM ROCK AV, San Jose
# 14     CANON VISTA DR & ALUM ROCK RD, San Jose
# 43     CAPITOL EX & BLUEFIELD DR (L), San Jose
# 46          SUNNY CT & BONITA AV (L), San Jose
# 58  RAJKOVICH WY & CALCATERRA DR (L), San Jose
#
#                                    intersection3  \
# 13      ALUM ROCK AV & MT. HAMILTON RD, San Jose
# 14        ALUM ROCK RD & EAST TERMINUS, San Jose
# 43     BLUEFIELD DR (L) & ROSENBAUM AV, San Jose
# 46           BONITA AV (L) & HERALD AV, San Jose
# 58  CALCATERRA DR (L) & SPRING HILL WY, San Jose
#
#                                    intersection4
# 13      MT. HAMILTON RD & ALUM ROCK AV, San Jose
# 14        EAST TERMINUS & ALUM ROCK RD, San Jose
# 43     ROSENBAUM AV & BLUEFIELD DR (L), San Jose
# 46           HERALD AV & BONITA AV (L), San Jose
# 58  SPRING HILL WY & CALCATERRA DR (L), San Jose

# %%
speed['F85th'].fillna(1.1*speed['SPD'], inplace = True)
speed['F50th'].fillna(speed['SPD'], inplace = True)
speed['SPD']
speed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 16 columns):
# STREET           580 non-null object
# START            580 non-null object
# END_             580 non-null object
# SPD              580 non-null int64
# LEN              575 non-null float64
# ACC              577 non-null float64
# VOL              576 non-null float64
# F85th            580 non-null float64
# LOCAL            580 non-null int64
# F50th            580 non-null float64
# lat              580 non-null float64
# lng              580 non-null float64
# intersection1    580 non-null object
# intersection2    580 non-null object
# intersection3    580 non-null object
# intersection4    580 non-null object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 72.6+ KB

# %%
plt.boxplot(speed["lat"])
quartile_1, quartile_3 = np.percentile(speed["lat"], [25, 75])
print(min(speed["lat"]))
iqr = quartile_3 - quartile_1
lower_bound = quartile_1 - (iqr * 1.5)
upper_bound = quartile_3 + (iqr * 1.5)
np.where((speed["lat"] > upper_bound) | (speed["lat"] < lower_bound))
# Out:
# 37.151166
# (array([482]),)

# %%
plt.boxplot(speed["lng"])
quartile_1, quartile_3 = np.percentile(speed["lng"], [25, 75])
iqr = quartile_3 - quartile_1
lower_bound = quartile_1 - (iqr * 1.5)
upper_bound = quartile_3 + (iqr * 1.5)
np.where((speed["lng"] > upper_bound) | (speed["lng"] < lower_bound))
# Out:
# (array([ 44, 109, 285, 295, 313, 399]),)

# %% [markdown]
# drop na

# %%
speed = speed.dropna()
speed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 574 entries, 0 to 579
# Data columns (total 16 columns):
# STREET           574 non-null object
# START            574 non-null object
# END_             574 non-null object
# SPD              574 non-null int64
# LEN              574 non-null float64
# ACC              574 non-null float64
# VOL              574 non-null float64
# F85th            574 non-null float64
# LOCAL            574 non-null int64
# F50th            574 non-null float64
# lat              574 non-null float64
# lng              574 non-null float64
# intersection1    574 non-null object
# intersection2    574 non-null object
# intersection3    574 non-null object
# intersection4    574 non-null object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 76.2+ KB

# %% [markdown]
# visulization

# %%
speed.plot.scatter(x = "lng", y = "lat", alpha = 0.4, c = speed["SPD"], label = "traffic", cmap=plt.get_cmap("jet"), figsize = (10, 7))
plt.legend()
plt.show()

# %%
speed.head(10)
plt.hist(speed.SPD, bins=50)
plt.show()

# %% [markdown]
# write speed df into csv file

# %%
speed.to_csv(r'speed_done.csv')

# %% [markdown]
# read crash data

# %%
accident = pd.read_csv("crash.csv")
accident.shape
# Out:
# (940, 13)

# %% [markdown]
# remove reduntante attribute, rename some attributes

# %%
accident = accident.drop(["AccidentId","ESRI_OID","GlobalID","Fatal_MajorInjuries"],axis=1)
accident = accident.rename(columns={'X': 'LONGITUDE', 'Y': 'LATITUDE','AccidentDateTime':'Date','AStreetNameAndSuffix':'AStreet','BStreetNameAndSuffix':'BStreet'})

# %% [markdown]
# change Date attribute to yyyymmdd

# %%
for i in range(0,10):
    date = accident.iloc[i].Date
    accident.at[i, 'Date'] = date[0:10].replace('-','')
accident.head(10)
# Out:
#     LONGITUDE   LATITUDE      Date      AStreet          BStreet  \
# 0 -121.876246  37.259063  20160318   ALMADEN EX        CHERRY AV
# 1 -121.815356  37.358727  20160315  LANCELOT LN         STORY RD
# 2 -121.819160  37.356147  20170323     STORY RD         WHITE RD
# 3 -121.827576  37.324070  20170328      KING RD      SEMINOLE WY
# 4 -121.852886  37.306752  20170331   PARROTT ST         TENTH ST
# 5 -121.871524  37.327908  20170518  SINCLAIR FR         TENTH ST
# 6 -121.894272  37.257455  20170508   BRANHAM LN  VIA DE CABALLE
# 7 -121.901664  37.309271  20170316   EL ABRA WY       LINCOLN AV
# 8 -121.884835  37.347696  20170317  ELEVENTH ST    WASHINGTON ST
# 9 -121.888104  37.325197  20170321   ALMADEN BL          REED ST
#
#    FatalInjuries  MajorInjuries   Involving          Nearest_Intersection
# 0              0              1  Pedestrian        ALMADEN EX & CHERRY AV
# 1              0              1  Pedestrian        LANCELOT LN & STORY RD
# 2              0              1   Bicyclist           STORY RD & WHITE RD
# 3              0              1  Pedestrian         KING RD & SEMINOLE WY
# 4              0              1    Motorist         PARROTT ST & TENTH ST
# 5              1              0    Motorist        SINCLAIR FR & TENTH ST
# 6              1              0    Motorist  BRANHAM LN & VIA DE CABALLE
# 7              0              1    Motorist       EL ABRA WY & LINCOLN AV
# 8              0              1    Motorist   ELEVENTH ST & WASHINGTON ST
# 9              0              1  Pedestrian          ALMADEN BL & REED ST

# %% [markdown]
# change inolving into numerical: Motorist:0, Pedestrian:1, Bicyclist:2

# %%
accident["Involving"].value_counts()
# Out:
# Motorist      504
# Pedestrian    300
# Bicyclist     136
# Name: Involving, dtype: int64

# %%
accident = accident.replace("Motorist","0")
accident = accident.replace("Pedestrian","1")
accident = accident.replace("Bicyclist","2")
accident["Involving"].value_counts()
# Out:
# 0    504
# 1    300
# 2    136
# Name: Involving, dtype: int64

# %% [markdown]
# concat speed dataset with accident dataset;
# if the exact intersection cannot find in the speed data, I use the same street with another nearst intersection instead. The neast intersection is defined by the intersection with shortest mahhatton distance instead

# %%
dataset = pd.DataFrame(columns = ['LONGITUDE', 'LATITUDE', 'Date', 'AStreet', 'BStreet', 'FatalInjuries',
       'MajorInjuries', 'Involving', 'Nearest_Intersection', 'SPD', 'LEN', 'ACC', 'VOL', 'F85th', 'LOCAL',
       'F50th'])
num = 0
#for i in range(0,accident.shape[0]):
for i in range(0,accident.shape[0]):
    A = accident.iloc[i].Nearest_Intersection
    B = accident.iloc[i].AStreet
    C = accident.iloc[i].BStreet
    lat = accident.iloc[i].LATITUDE
    lng = accident.iloc[i].LONGITUDE
    i1 = speed.loc[speed["intersection1"].isin([A]) | speed["intersection2"].isin([A]) | speed["intersection3"].isin([A]) | speed["intersection4"].isin([A])]
    i2 = speed.loc[speed["STREET"].isin([B]) | speed["START"].isin([B]) | speed["END_"].isin([B])]
    i3 = speed.loc[speed["STREET"].isin([C]) | speed["START"].isin([C]) | speed["END_"].isin([C])]
    a = accident.iloc[i][0:9]
    if i1.shape[0] != 0:
        b = i1.iloc[0][3:10]
        c = pd.concat([a, b], sort=False,)
        num = num + 1
    elif i2.shape[0] != 0:
        arr = []
        for n in range(0, i2.shape[0]):
            lat1 = i2.iloc[n].lat
            lng1 = i2.iloc[n].lng
            dis = abs(lat - lat1) + abs(lng - lng1)
            arr.append(dis)
        arr.index(min(arr))
        b = i2.iloc[arr.index(min(arr))][3:10]
        c = pd.concat([a, b], sort=False,)
        num = num + 1
    elif i3.shape[0] != 0:
        arr = []
        for m in range(0, i3.shape[0]):
            lat2 = i3.iloc[m].lat
            lng2 = i3.iloc[m].lng
            dis = abs(lat - lat2) + abs(lng - lng2)
            arr.append(dis)
        arr.index(min(arr))
        b = i3.iloc[arr.index(min(arr))][3:10]
        c = pd.concat([a, b], sort=False,)
    else: c = a
    dataset = dataset.append(c, ignore_index=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 16 columns):
# LONGITUDE               940 non-null float64
# LATITUDE                940 non-null float64
# Date                    940 non-null object
# AStreet                 940 non-null object
# BStreet                 940 non-null object
# FatalInjuries           940 non-null object
# MajorInjuries           940 non-null object
# Involving               940 non-null object
# Nearest_Intersection    940 non-null object
# SPD                     853 non-null object
# LEN                     853 non-null float64
# ACC                     853 non-null float64
# VOL                     853 non-null float64
# F85th                   853 non-null float64
# LOCAL                   853 non-null object
# F50th                   853 non-null float64
# dtypes: float64(7), object(9)
# memory usage: 117.6+ KB

# %% [markdown]
# drop NA for the street cannot find any traffic information at all

# %%
dataset = dataset.dropna()
dataset.info()
dataset.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 853 entries, 0 to 939
# Data columns (total 16 columns):
# LONGITUDE               853 non-null float64
# LATITUDE                853 non-null float64
# Date                    853 non-null object
# AStreet                 853 non-null object
# BStreet                 853 non-null object
# FatalInjuries           853 non-null object
# MajorInjuries           853 non-null object
# Involving               853 non-null object
# Nearest_Intersection    853 non-null object
# SPD                     853 non-null object
# LEN                     853 non-null float64
# ACC                     853 non-null float64
# VOL                     853 non-null float64
# F85th                   853 non-null float64
# LOCAL                   853 non-null object
# F50th                   853 non-null float64
# dtypes: float64(7), object(9)
# memory usage: 113.3+ KB
# (853, 16)

# %%
dataset.head(10)
# Out:
#     LONGITUDE   LATITUDE      Date      AStreet          BStreet  \
# 0 -121.876246  37.259063  20160318   ALMADEN EX        CHERRY AV
# 1 -121.815356  37.358727  20160315  LANCELOT LN         STORY RD
# 2 -121.819160  37.356147  20170323     STORY RD         WHITE RD
# 3 -121.827576  37.324070  20170328      KING RD      SEMINOLE WY
# 4 -121.852886  37.306752  20170331   PARROTT ST         TENTH ST
# 5 -121.871524  37.327908  20170518  SINCLAIR FR         TENTH ST
# 6 -121.894272  37.257455  20170508   BRANHAM LN  VIA DE CABALLE
# 7 -121.901664  37.309271  20170316   EL ABRA WY       LINCOLN AV
# 8 -121.884835  37.347696  20170317  ELEVENTH ST    WASHINGTON ST
# 9 -121.888104  37.325197  20170321   ALMADEN BL          REED ST
#
#   FatalInjuries MajorInjuries Involving          Nearest_Intersection SPD  \
# 0             0             1         1        ALMADEN EX & CHERRY AV  35
# 1             0             1         1        LANCELOT LN & STORY RD  30
# 2             0             1         2           STORY RD & WHITE RD  30
# 3             0             1         1         KING RD & SEMINOLE WY  35
# 4             0             1         0         PARROTT ST & TENTH ST  40
# 5             1             0         0        SINCLAIR FR & TENTH ST  25
# 6             1             0         0  BRANHAM LN & VIA DE CABALLE   30
# 7             0             1         0       EL ABRA WY & LINCOLN AV  30
# 8             0             1         0   ELEVENTH ST & WASHINGTON ST  25
# 9             0             1         1          ALMADEN BL & REED ST  25
#
#        LEN   ACC      VOL  F85th LOCAL  F50th
# 0  13450.0  54.0   7200.0   37.3     0   33.3
# 1   3650.0   5.0   4800.0   33.0     0   30.0
# 2   2600.0  25.0   6150.0   33.5     0   29.5
# 3   5400.0  38.0  11050.0   39.3     0   34.7
# 4   5000.0  37.0  12800.0   42.5     0   39.0
# 5   2260.0  10.0   2700.0   27.5     0   23.5
# 6   5400.0   9.0   3850.0   34.5     0   31.0
# 7   3775.0  19.0  11300.0   32.5     0   29.5
# 8   3700.0  60.0   7450.0   26.5     0   23.5
# 9   2900.0  17.0   5100.0   30.0     1   25.0

# %% [markdown]
# write traffic and accident df into csv file

# %%
dataset.to_csv(r'accident_speed.csv')
