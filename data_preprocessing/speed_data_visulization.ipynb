# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
import seaborn as sns

# %%
speed = pd.read_csv('speed_done.csv')

# %%
speed.plot.scatter(x = "lng", y = "lat", alpha = 0.4, c = speed["ACC"], label = "traffic", cmap=plt.get_cmap("jet"), figsize = (10, 7))
plt.legend()
plt.show()

# %%
speed.plot.scatter(x = "lng", y = "lat", alpha = 0.4, c = speed["SPD"], label = "traffic", cmap=plt.get_cmap("jet"), figsize = (10, 7))
plt.legend()
plt.show()

# %%
speed.plot.scatter(x = "lng", y = "lat", alpha = 0.4, c = speed['VOL'], cmap=plt.get_cmap("jet"), figsize = (10, 7))
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
speed.sort_values(by=['ACC'],ascending = False).head(10)
# Out:
#      Unnamed: 0            STREET          START           END_  SPD      LEN  \
# 69           70        CAPITOL EX  McLAUGHLIN AV          I-680   45  23000.0
# 23           24        CAPITOL EX          SR-87  McLAUGHLIN AV   50  60450.0
# 227         228     McLAUGHLIN AV     CAPITOL EX     WILLIAM ST   35  19200.0
# 181         182           KING RD       ABORN RD       STORY RD   35  14500.0
# 473         477        ALMADEN EX     COLEMAN RD     BRANHAM LN   45   6900.0
# 472         476        ALMADEN EX     BRANHAM LN          SR-87   50  16000.0
# 431         433        ALMADEN EX       HARRY RD     COLEMAN RD   50  21700.0
# 226         227          McKEE RD        KING RD       TOYON AV   40  13100.0
# 390         392          TULLY RD    MONTEREY RD     CAPITOL EX   40  17800.0
# 363         365  STEVENS CREEK BL    SARATOGA AV          I-880   35   8450.0
#
#        ACC      VOL  F85th  LOCAL  F50th        lat         lng  \
# 69   670.0  60450.0   50.0      0   46.0  37.300300 -121.820933
# 23   670.0  50900.0   51.0      0   46.0  37.276059 -121.867407
# 227  411.0  22750.0   38.8      0   34.8  37.300300 -121.820933
# 181  300.0  23900.0   37.8      0   34.0  37.310165 -121.813365
# 473  288.0  64000.0   52.0      0   48.0  37.242555 -121.875061
# 472  288.0  35000.0   53.0      0   50.0  37.263010 -121.876830
# 431  288.0  20500.0   51.0      0   50.0  37.211053 -121.806949
# 226  281.0  29500.0   41.3      0   37.3  37.358019 -121.860729
# 390  240.0  40700.0   42.3      0   38.0  37.303626 -121.861067
# 363  218.0  35050.0   39.5      0   35.5  37.323129 -121.970040
#
#                                 intersection1  \
# 69       CAPITOL EX & McLAUGHLIN AV, San Jose
# 23               CAPITOL EX & SR-87, San Jose
# 227      McLAUGHLIN AV & CAPITOL EX, San Jose
# 181              KING RD & ABORN RD, San Jose
# 473         ALMADEN EX & COLEMAN RD, San Jose
# 472         ALMADEN EX & BRANHAM LN, San Jose
# 431           ALMADEN EX & HARRY RD, San Jose
# 226              McKEE RD & KING RD, San Jose
# 390          TULLY RD & MONTEREY RD, San Jose
# 363  STEVENS CREEK BL & SARATOGA AV, San Jose
#
#                                 intersection2  \
# 69       McLAUGHLIN AV & CAPITOL EX, San Jose
# 23               SR-87 & CAPITOL EX, San Jose
# 227      CAPITOL EX & McLAUGHLIN AV, San Jose
# 181              ABORN RD & KING RD, San Jose
# 473         COLEMAN RD & ALMADEN EX, San Jose
# 472         BRANHAM LN & ALMADEN EX, San Jose
# 431           HARRY RD & ALMADEN EX, San Jose
# 226              KING RD & McKEE RD, San Jose
# 390          MONTEREY RD & TULLY RD, San Jose
# 363  SARATOGA AV & STEVENS CREEK BL, San Jose
#
#                             intersection3  \
# 69           CAPITOL EX & I-680, San Jose
# 23   CAPITOL EX & McLAUGHLIN AV, San Jose
# 227  McLAUGHLIN AV & WILLIAM ST, San Jose
# 181          KING RD & STORY RD, San Jose
# 473     ALMADEN EX & BRANHAM LN, San Jose
# 472          ALMADEN EX & SR-87, San Jose
# 431     ALMADEN EX & COLEMAN RD, San Jose
# 226         McKEE RD & TOYON AV, San Jose
# 390       TULLY RD & CAPITOL EX, San Jose
# 363    STEVENS CREEK BL & I-880, San Jose
#
#                             intersection4
# 69           I-680 & CAPITOL EX, San Jose
# 23   McLAUGHLIN AV & CAPITOL EX, San Jose
# 227  WILLIAM ST & McLAUGHLIN AV, San Jose
# 181          STORY RD & KING RD, San Jose
# 473     BRANHAM LN & ALMADEN EX, San Jose
# 472          SR-87 & ALMADEN EX, San Jose
# 431     COLEMAN RD & ALMADEN EX, San Jose
# 226         TOYON AV & McKEE RD, San Jose
# 390       CAPITOL EX & TULLY RD, San Jose
# 363    I-880 & STEVENS CREEK BL, San Jose

# %%
speed.keys()
# Out:
# Index(['Unnamed: 0', 'STREET', 'START', 'END_', 'SPD', 'LEN', 'ACC', 'VOL',
#        'F85th', 'LOCAL', 'F50th', 'lat', 'lng', 'intersection1',
#        'intersection2', 'intersection3', 'intersection4'],
#       dtype='object')

# %%
data = speed.drop(['Unnamed: 0', 'STREET', 'START', 'LOCAL', 'END_','lat', 'lng', 'intersection1', 'intersection2', 'intersection3', 'intersection4'], axis = 1)

# %%
scatter_matrix(data, figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1159b3518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115978be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115981a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1158a4f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1157652b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1157dd9b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1158b5c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1149830b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1149830f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115969b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11575e908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1158226a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1158c1c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1159450f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115940748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11585bcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x102c2b278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x102c537f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x102c7ad68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1149a6320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1149cc898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1149f4e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114a263c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114a4d940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x114a76eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114aa8470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114acf9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114af8f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114b27518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114b50a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x114b81048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11610a5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116136b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1161650f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11618d668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1161b6be0>]],
#       dtype=object)

# %%
data.head(5)

# %%
corr = data.corr()
cmap = sns.diverging_palette(220, 5, as_cmap=True)
#g = sns.heatmap(corr,  vmax=.3, center=0,
            #square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True, fmt='.2f', cmap = cmap)
g = sns.heatmap(corr, annot=True,  cmap = 'coolwarm')
sns.despine()
g.figure.set_size_inches(14,10)
plt.show()

# %%
data.keys()
# Out:
# Index(['SPD', 'LEN', 'ACC', 'VOL', 'F85th', 'F50th'], dtype='object')

# %%
data = data.drop(['LEN', 'ACC', 'VOL'], axis=1)

# %%
corr = data.corr()
cmap = sns.diverging_palette(220, 5, as_cmap=True)
#g = sns.heatmap(corr,  vmax=.3, center=0,
            #square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True, fmt='.2f', cmap = cmap)
g = sns.heatmap(corr, annot=True, cmap = 'coolwarm')
sns.despine()
g.figure.set_size_inches(14,10)
plt.show()
